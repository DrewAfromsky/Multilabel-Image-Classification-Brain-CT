# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.1.0

# %%
import itertools
import os

import matplotlib.pylab as plt
import numpy as np

import tensorflow as tf
import tensorflow_hub as hub

print("TF version:", tf.__version__)
print("Hub version:", hub.__version__)
print("GPU is", "available" if tf.config.list_physical_devices('GPU') else "NOT AVAILABLE")
# Out:
# TF version: 2.1.0
# Hub version: 0.7.0
# GPU is available

# %% [markdown]
# # Set up the Colab environment with the train and test zip files

# %%
import os
os.getcwd()
# Out:
# '/kaggle/working'

# %%
input_shape = [128, 128, 3]

# %%
# %cd /kaggle/input
# Out:
# /kaggle/input

# %%
# %cd ..
# Out:
# /kaggle

# %%
ls
# Out:
# input/  lib/  working/

# %% [markdown]
# # Create the train, validation, and test datasets

# %%
import pandas as pd
# View the csv file containing the labels for the training images
train_labels = pd.read_csv("/kaggle/input/behold_coding_challenge_train.csv")
train_labels.head()
# Out:
#    Unnamed: 0       ID  epidural  intraparenchymal  subarachnoid
# 0           0  train_0         1                 0             1
# 1           1  train_1         1                 0             0
# 2           2  train_2         1                 0             1
# 3           3  train_3         1                 0             1
# 4           4  train_4         1                 0             0

# %%
train_labels = train_labels.drop(['Unnamed: 0'],axis=1)

# %%
train_labels
# Out:
#               ID  epidural  intraparenchymal  subarachnoid
# 0        train_0         1                 0             1
# 1        train_1         1                 0             0
# 2        train_2         1                 0             1
# 3        train_3         1                 0             1
# 4        train_4         1                 0             0
# ...          ...       ...               ...           ...
# 8537  train_8588         0                 0             0
# 8538  train_8589         0                 0             0
# 8539  train_8590         0                 0             0
# 8540  train_8591         0                 0             0
# 8541  train_8592         0                 0             0
#
# [8542 rows x 4 columns]

# %%
train_labels.shape
# Out:
# (8542, 4)

# %%
from tensorflow.keras.preprocessing import image
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import glob
import numpy as np

X = []

for i in tqdm(range(train_labels.shape[0])):
    path = "/kaggle/input/train_images/train_images/" + train_labels['ID'][i] + '.png'
    img = image.load_img(path, target_size=(input_shape))
    img = image.img_to_array(img)
#     img = img/255.0
    X.append(img)

X = np.array(X)
# Out:
# 100%|██████████| 8542/8542 [00:18<00:00, 465.08it/s]

# %%
os.getcwd()
# Out:
# '/kaggle'

# %%
y = train_labels.drop(['ID'], axis = 1)
y = y.to_numpy()
y.shape
# Out:
# (8542, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(X[1])

# %%
# !pip install iterative-stratification
# Out:
# Collecting iterative-stratification
#   Downloading https://files.pythonhosted.org/packages/9d/79/9ba64c8c07b07b8b45d80725b2ebd7b7884701c1da34f70d4749f7b45f9a/iterative_stratification-0.1.6-py3-none-any.whl
# Requirement already satisfied: scipy in /opt/conda/lib/python3.6/site-packages (from iterative-stratification) (1.4.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.6/site-packages (from iterative-stratification) (1.18.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.6/site-packages (from iterative-stratification) (0.21.3)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.6/site-packages (from scikit-learn->iterative-stratification) (0.14.1)
# Installing collected packages: iterative-stratification
# Successfully installed iterative-stratification-0.1.6

# %%
######################################
# Multi-Label Stratified Shuffle Split
######################################

from iterstrat.ml_stratifiers import MultilabelStratifiedShuffleSplit

msss = MultilabelStratifiedShuffleSplit(n_splits=3, test_size=0.15, random_state=0)

for train_index, val_index in msss.split(X, y):
    print("TRAIN:", train_index, "VAL:", val_index)
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
# Out:
# TRAIN: [   0    1    2 ... 8538 8540 8541] VAL: [  13   21   24 ... 8529 8530 8539]
# TRAIN: [   0    1    2 ... 8539 8540 8541] VAL: [  11   21   29 ... 8505 8511 8524]
# TRAIN: [   0    3    4 ... 8539 8540 8541] VAL: [   1    2    8 ... 8500 8509 8529]

# %%
######################################
# Repeated Multi label Stratified KFold
######################################

# from iterstrat.ml_stratifiers import RepeatedMultilabelStratifiedKFold

# rmskf = RepeatedMultilabelStratifiedKFold(n_splits=3, n_repeats=2, random_state=0)

# for train_index, val_index in rmskf.split(X, y):
#    print("TRAIN:", train_index, "VAL:", val_index)
#    X_train, X_val = X[train_index], X[val_index]
#    y_train, y_val = y[train_index], y[val_index]

# %%
######################################
# Multi label Stratified KFold
######################################

# from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

# mskf = MultilabelStratifiedKFold(n_splits=3, random_state=0)

# for train_index, val_index in mskf.split(X, y):
#    print("TRAIN:", train_index, "VAL:", val_index)
#    X_train, X_val = X[train_index], X[val_index]
#    y_train, y_val = y[train_index], y[val_index]

# %%
#########################################################
####### Standard train-test-split with validation #######
########## set of 15% and the data shuffled #############
#########################################################

# X_train, X_val, y_train, y_val = train_test_split(X, y, random_state = 0, test_size = 0.15, shuffle = True)

# %%
print('Train data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
# Out:
# Train data shape:  (7260, 128, 128, 3)
# Training labels shape:  (7260, 3)
# Validation data shape:  (1282, 128, 128, 3)
# Validation labels shape:  (1282, 3)

# %% [markdown]
# # Model Selection and Data Augmentation

# %%
from tensorflow.keras import models, layers
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout, AveragePooling2D, Conv2D
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.applications import NASNetLarge
from tensorflow.keras.applications import NASNetMobile
from tensorflow.keras.applications import ResNet50

# %%
############################
#### Data Augmentation #####
############################

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 30,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow(X_train, y_train, batch_size=16) # batch size = 16

val_generator = val_datagen.flow(X_val, y_val,batch_size=16) # batch size = 16

# %%
#############################
####### Resnet 50 ###########
#############################

# import tensorflow as tf
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import GlobalAveragePooling2D, Dense

# resnet50_feature_extractor = tf.keras.applications.resnet50.ResNet50(
#     include_top=False, weights='imagenet', input_shape=input_shape)

# frozen_layers, trainable_layers = [], []
# for layer in resnet50_feature_extractor.layers:
#     if isinstance(layer, tf.keras.layers.Conv2D):
#         layer.trainable = False
#         frozen_layers.append(layer.name)
#     else:
#         if len(layer.trainable_weights) > 0:
#             # We list as "trainable" only the layers with trainable parameters.
#             trainable_layers.append(layer.name)

# %%
# resnet50_feature_extractor.summary()

# %%
# log_begin_red, log_begin_blue, log_begin_green = '\033[91m', '\n\033[94m', '\033[92m'
# log_begin_bold, log_begin_underline = '\033[1m', '\033[4m'
# log_end_format = '\033[0m'

# # Logging the lists of frozen/trainable layers:
# print("{2}Layers we froze:{4} {0} ({3}total = {1}{4}).".format(
#     frozen_layers, len(frozen_layers), log_begin_red, log_begin_bold, log_end_format))

# print("\n{2}Layers which will be fine-tuned:{4} {0} ({3}total = {1}{4}).".format(
#     trainable_layers, len(trainable_layers), log_begin_blue, log_begin_bold, log_end_format))

# %%
##########################
###### Inception V3 ######
##########################

num_classes = 3

model = tf.keras.Sequential([
                         hub.KerasLayer("https://tfhub.dev/google/tf2-preview/inception_v3/feature_vector/4", 
                         output_shape=[2048],
                         trainable=False),  # Can be True, see below.
                         tf.keras.layers.BatchNormalization(),
                         tf.keras.layers.Dropout(rate = 0.5), # change to 0.5 next
                        #  tf.keras.layers.GlobalAveragePooling2D(data_format = 'channels_last'),
                         tf.keras.layers.Dense(num_classes, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.l2(0.0001))
                        ])
model.build([None, 128, 128, 3])  # Batch input shape.

#########################
###### ResNetV2 50 ######
#########################

# model = tf.keras.Sequential([
#                          hub.KerasLayer("https://tfhub.dev/google/imagenet/resnet_v2_50/feature_vector/4", 
#                          trainable=False),  # Can be True, see below.
#                          tf.keras.layers.BatchNormalization(),
#                          tf.keras.layers.Dropout(rate = 0.2),
#                         #  tf.keras.layers.GlobalAveragePooling2D(data_format = 'channels_last'),
#                          tf.keras.layers.Dense(num_classes, activation='sigmoid', kernel_regularizer=tf.keras.regularizers.l2(0.0001))
#                         ])
# model.build([None, 128, 128, 3])  # Batch input shape.

# features = resnet50_feature_extractor.output
# xx = BatchNormalization()(features)
# yy = Dropout(0.2)(xx)
# avg_pool = GlobalAveragePooling2D(data_format='channels_last')(yy)
# predictions = Dense(num_classes, activation='sigmoid')(avg_pool)

# resnet50_freeze = Model(resnet50_feature_extractor.input, predictions)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     multiple                  21802784
# _________________________________________________________________
# batch_normalization (BatchNo multiple                  8192
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  6147
# =================================================================
# Total params: 21,817,123
# Trainable params: 10,243
# Non-trainable params: 21,806,880
# _________________________________________________________________

# %% [markdown]
# # Model Training

# %%
num_epochs = 100

# model = resnet50_freeze

# optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

optimizer = tf.keras.optimizers.Adam(learning_rate=0.00001)

model.compile(loss = 'binary_crossentropy',
              optimizer = optimizer,
              metrics=['acc', tf.keras.metrics.Recall(), tf.keras.metrics.Precision(), tf.keras.metrics.BinaryCrossentropy()])

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

history_freeze = model.fit(train_generator,
                           epochs = num_epochs, 
                           validation_data = val_generator,
                           callbacks = [callback]
                           )
# Out:
# Train for 454 steps, validate for 81 steps
# Epoch 1/100
# 454/454 [==============================] - 41s 90ms/step - loss: 1.0186 - acc: 0.5126 - recall: 0.4974 - precision: 0.2592 - binary_crossentropy: 1.0180 - val_loss: 0.8394 - val_acc: 0.5200 - val_recall: 0.5503 - val_precision: 0.2757 - val_binary_crossentropy: 0.8416
# Epoch 2/100
# 454/454 [==============================] - 30s 65ms/step - loss: 0.9309 - acc: 0.5435 - recall: 0.5251 - precision: 0.2835 - binary_crossentropy: 0.9302 - val_loss: 0.7723 - val_acc: 0.5666 - val_recall: 0.5708 - val_precision: 0.3080 - val_binary_crossentropy: 0.7747
# Epoch 3/100
# 454/454 [==============================] - 30s 67ms/step - loss: 0.8746 - acc: 0.5665 - recall: 0.5380 - precision: 0.3010 - binary_crossentropy: 0.8739 - val_loss: 0.7136 - val_acc: 0.6071 - val_recall: 0.5524 - val_precision: 0.3335 - val_binary_crossentropy: 0.7161
# Epoch 4/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.8253 - acc: 0.5926 - recall: 0.5534 - precision: 0.3227 - binary_crossentropy: 0.8247 - val_loss: 0.6761 - val_acc: 0.6347 - val_recall: 0.5688 - val_precision: 0.3600 - val_binary_crossentropy: 0.6785
# Epoch 5/100
# 454/454 [==============================] - 30s 67ms/step - loss: 0.7922 - acc: 0.6112 - recall: 0.5382 - precision: 0.3340 - binary_crossentropy: 0.7915 - val_loss: 0.6404 - val_acc: 0.6648 - val_recall: 0.5791 - val_precision: 0.3909 - val_binary_crossentropy: 0.6426
# Epoch 6/100
# 454/454 [==============================] - 30s 65ms/step - loss: 0.7532 - acc: 0.6320 - recall: 0.5425 - precision: 0.3528 - binary_crossentropy: 0.7525 - val_loss: 0.6141 - val_acc: 0.6895 - val_recall: 0.5862 - val_precision: 0.4192 - val_binary_crossentropy: 0.6164
# Epoch 7/100
# 454/454 [==============================] - 30s 67ms/step - loss: 0.7369 - acc: 0.6475 - recall: 0.5479 - precision: 0.3683 - binary_crossentropy: 0.7363 - val_loss: 0.5809 - val_acc: 0.7132 - val_recall: 0.5606 - val_precision: 0.4472 - val_binary_crossentropy: 0.5831
# Epoch 8/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.7133 - acc: 0.6559 - recall: 0.5396 - precision: 0.3753 - binary_crossentropy: 0.7126 - val_loss: 0.5617 - val_acc: 0.7306 - val_recall: 0.5647 - val_precision: 0.4733 - val_binary_crossentropy: 0.5639
# Epoch 9/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.6875 - acc: 0.6674 - recall: 0.5314 - precision: 0.3862 - binary_crossentropy: 0.6868 - val_loss: 0.5461 - val_acc: 0.7389 - val_recall: 0.5667 - val_precision: 0.4868 - val_binary_crossentropy: 0.5482
# Epoch 10/100
# 454/454 [==============================] - 30s 65ms/step - loss: 0.6599 - acc: 0.6826 - recall: 0.5285 - precision: 0.4034 - binary_crossentropy: 0.6592 - val_loss: 0.5272 - val_acc: 0.7525 - val_recall: 0.5513 - val_precision: 0.5105 - val_binary_crossentropy: 0.5294
# Epoch 11/100
# 454/454 [==============================] - 30s 67ms/step - loss: 0.6602 - acc: 0.6873 - recall: 0.5193 - precision: 0.4079 - binary_crossentropy: 0.6596 - val_loss: 0.5119 - val_acc: 0.7608 - val_recall: 0.5421 - val_precision: 0.5269 - val_binary_crossentropy: 0.5141
# Epoch 12/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.6288 - acc: 0.7012 - recall: 0.5177 - precision: 0.4261 - binary_crossentropy: 0.6282 - val_loss: 0.5027 - val_acc: 0.7668 - val_recall: 0.5411 - val_precision: 0.5394 - val_binary_crossentropy: 0.5049
# Epoch 13/100
# 454/454 [==============================] - 30s 67ms/step - loss: 0.6191 - acc: 0.7072 - recall: 0.5150 - precision: 0.4343 - binary_crossentropy: 0.6185 - val_loss: 0.4913 - val_acc: 0.7709 - val_recall: 0.5277 - val_precision: 0.5497 - val_binary_crossentropy: 0.4937
# Epoch 14/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.6102 - acc: 0.7160 - recall: 0.5115 - precision: 0.4470 - binary_crossentropy: 0.6095 - val_loss: 0.4817 - val_acc: 0.7746 - val_recall: 0.5113 - val_precision: 0.5602 - val_binary_crossentropy: 0.4841
# Epoch 15/100
# 454/454 [==============================] - 30s 67ms/step - loss: 0.6010 - acc: 0.7209 - recall: 0.5046 - precision: 0.4542 - binary_crossentropy: 0.6004 - val_loss: 0.4744 - val_acc: 0.7761 - val_recall: 0.5072 - val_precision: 0.5646 - val_binary_crossentropy: 0.4767
# Epoch 16/100
# 454/454 [==============================] - 30s 65ms/step - loss: 0.5883 - acc: 0.7284 - recall: 0.5030 - precision: 0.4665 - binary_crossentropy: 0.5877 - val_loss: 0.4681 - val_acc: 0.7782 - val_recall: 0.5103 - val_precision: 0.5693 - val_binary_crossentropy: 0.4704
# Epoch 17/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.5776 - acc: 0.7343 - recall: 0.5024 - precision: 0.4769 - binary_crossentropy: 0.5770 - val_loss: 0.4622 - val_acc: 0.7803 - val_recall: 0.4959 - val_precision: 0.5771 - val_binary_crossentropy: 0.4647
# Epoch 18/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.5747 - acc: 0.7366 - recall: 0.4912 - precision: 0.4805 - binary_crossentropy: 0.5741 - val_loss: 0.4574 - val_acc: 0.7816 - val_recall: 0.4887 - val_precision: 0.5819 - val_binary_crossentropy: 0.4599
# Epoch 19/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.5617 - acc: 0.7417 - recall: 0.4943 - precision: 0.4903 - binary_crossentropy: 0.5611 - val_loss: 0.4534 - val_acc: 0.7826 - val_recall: 0.4908 - val_precision: 0.5844 - val_binary_crossentropy: 0.4559
# Epoch 20/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.5633 - acc: 0.7458 - recall: 0.4863 - precision: 0.4981 - binary_crossentropy: 0.5628 - val_loss: 0.4500 - val_acc: 0.7852 - val_recall: 0.4918 - val_precision: 0.5914 - val_binary_crossentropy: 0.4526
# Epoch 21/100
# 454/454 [==============================] - 30s 67ms/step - loss: 0.5603 - acc: 0.7425 - recall: 0.4758 - precision: 0.4914 - binary_crossentropy: 0.5597 - val_loss: 0.4474 - val_acc: 0.7837 - val_recall: 0.4949 - val_precision: 0.5864 - val_binary_crossentropy: 0.4499
# Epoch 22/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.5518 - acc: 0.7510 - recall: 0.4794 - precision: 0.5089 - binary_crossentropy: 0.5512 - val_loss: 0.4447 - val_acc: 0.7863 - val_recall: 0.4784 - val_precision: 0.5974 - val_binary_crossentropy: 0.4473
# Epoch 23/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.5456 - acc: 0.7509 - recall: 0.4776 - precision: 0.5088 - binary_crossentropy: 0.5449 - val_loss: 0.4426 - val_acc: 0.7860 - val_recall: 0.4856 - val_precision: 0.5950 - val_binary_crossentropy: 0.4452
# Epoch 24/100
# 454/454 [==============================] - 30s 65ms/step - loss: 0.5438 - acc: 0.7541 - recall: 0.4727 - precision: 0.5160 - binary_crossentropy: 0.5432 - val_loss: 0.4405 - val_acc: 0.7865 - val_recall: 0.4825 - val_precision: 0.5972 - val_binary_crossentropy: 0.4431
# Epoch 25/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.5435 - acc: 0.7508 - recall: 0.4742 - precision: 0.5087 - binary_crossentropy: 0.5430 - val_loss: 0.4384 - val_acc: 0.7865 - val_recall: 0.4856 - val_precision: 0.5965 - val_binary_crossentropy: 0.4410
# Epoch 26/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.5421 - acc: 0.7528 - recall: 0.4716 - precision: 0.5132 - binary_crossentropy: 0.5416 - val_loss: 0.4369 - val_acc: 0.7873 - val_recall: 0.4825 - val_precision: 0.5995 - val_binary_crossentropy: 0.4396
# Epoch 27/100
# 454/454 [==============================] - 30s 67ms/step - loss: 0.5337 - acc: 0.7593 - recall: 0.4792 - precision: 0.5274 - binary_crossentropy: 0.5330 - val_loss: 0.4367 - val_acc: 0.7881 - val_recall: 0.4713 - val_precision: 0.6047 - val_binary_crossentropy: 0.4394
# Epoch 28/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.5281 - acc: 0.7608 - recall: 0.4734 - precision: 0.5313 - binary_crossentropy: 0.5275 - val_loss: 0.4345 - val_acc: 0.7878 - val_recall: 0.4723 - val_precision: 0.6037 - val_binary_crossentropy: 0.4372
# Epoch 29/100
# 454/454 [==============================] - 30s 67ms/step - loss: 0.5285 - acc: 0.7562 - recall: 0.4676 - precision: 0.5210 - binary_crossentropy: 0.5279 - val_loss: 0.4330 - val_acc: 0.7884 - val_recall: 0.4795 - val_precision: 0.6034 - val_binary_crossentropy: 0.4357
# Epoch 30/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.5234 - acc: 0.7619 - recall: 0.4709 - precision: 0.5340 - binary_crossentropy: 0.5229 - val_loss: 0.4318 - val_acc: 0.7894 - val_recall: 0.4743 - val_precision: 0.6079 - val_binary_crossentropy: 0.4345
# Epoch 31/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.5248 - acc: 0.7631 - recall: 0.4740 - precision: 0.5367 - binary_crossentropy: 0.5242 - val_loss: 0.4312 - val_acc: 0.7920 - val_recall: 0.4641 - val_precision: 0.6192 - val_binary_crossentropy: 0.4340
# Epoch 32/100
# 454/454 [==============================] - 30s 65ms/step - loss: 0.5253 - acc: 0.7613 - recall: 0.4637 - precision: 0.5332 - binary_crossentropy: 0.5248 - val_loss: 0.4295 - val_acc: 0.7925 - val_recall: 0.4754 - val_precision: 0.6173 - val_binary_crossentropy: 0.4322
# Epoch 33/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.5226 - acc: 0.7607 - recall: 0.4620 - precision: 0.5317 - binary_crossentropy: 0.5220 - val_loss: 0.4291 - val_acc: 0.7920 - val_recall: 0.4784 - val_precision: 0.6148 - val_binary_crossentropy: 0.4318
# Epoch 34/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.5212 - acc: 0.7619 - recall: 0.4666 - precision: 0.5344 - binary_crossentropy: 0.5205 - val_loss: 0.4281 - val_acc: 0.7941 - val_recall: 0.4764 - val_precision: 0.6220 - val_binary_crossentropy: 0.4308
# Epoch 35/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.5178 - acc: 0.7642 - recall: 0.4756 - precision: 0.5391 - binary_crossentropy: 0.5173 - val_loss: 0.4267 - val_acc: 0.7930 - val_recall: 0.4856 - val_precision: 0.6159 - val_binary_crossentropy: 0.4294
# Epoch 36/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.5167 - acc: 0.7646 - recall: 0.4702 - precision: 0.5408 - binary_crossentropy: 0.5162 - val_loss: 0.4260 - val_acc: 0.7936 - val_recall: 0.4805 - val_precision: 0.6190 - val_binary_crossentropy: 0.4287
# Epoch 37/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.5075 - acc: 0.7688 - recall: 0.4753 - precision: 0.5506 - binary_crossentropy: 0.5069 - val_loss: 0.4247 - val_acc: 0.7962 - val_recall: 0.4867 - val_precision: 0.6253 - val_binary_crossentropy: 0.4275
# Epoch 38/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.5125 - acc: 0.7688 - recall: 0.4747 - precision: 0.5506 - binary_crossentropy: 0.5120 - val_loss: 0.4242 - val_acc: 0.7975 - val_recall: 0.4918 - val_precision: 0.6278 - val_binary_crossentropy: 0.4270
# Epoch 39/100
# 454/454 [==============================] - 30s 65ms/step - loss: 0.5058 - acc: 0.7707 - recall: 0.4787 - precision: 0.5549 - binary_crossentropy: 0.5051 - val_loss: 0.4229 - val_acc: 0.7985 - val_recall: 0.4877 - val_precision: 0.6325 - val_binary_crossentropy: 0.4257
# Epoch 40/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.5054 - acc: 0.7711 - recall: 0.4753 - precision: 0.5563 - binary_crossentropy: 0.5048 - val_loss: 0.4226 - val_acc: 0.7980 - val_recall: 0.4856 - val_precision: 0.6315 - val_binary_crossentropy: 0.4253
# Epoch 41/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.5033 - acc: 0.7701 - recall: 0.4838 - precision: 0.5527 - binary_crossentropy: 0.5027 - val_loss: 0.4225 - val_acc: 0.7977 - val_recall: 0.4877 - val_precision: 0.6300 - val_binary_crossentropy: 0.4253
# Epoch 42/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.5002 - acc: 0.7721 - recall: 0.4738 - precision: 0.5593 - binary_crossentropy: 0.4995 - val_loss: 0.4220 - val_acc: 0.7995 - val_recall: 0.4743 - val_precision: 0.6408 - val_binary_crossentropy: 0.4248
# Epoch 43/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.4986 - acc: 0.7699 - recall: 0.4754 - precision: 0.5534 - binary_crossentropy: 0.4981 - val_loss: 0.4206 - val_acc: 0.8008 - val_recall: 0.4877 - val_precision: 0.6402 - val_binary_crossentropy: 0.4233
# Epoch 44/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.4999 - acc: 0.7727 - recall: 0.4794 - precision: 0.5600 - binary_crossentropy: 0.4993 - val_loss: 0.4205 - val_acc: 0.8003 - val_recall: 0.4764 - val_precision: 0.6427 - val_binary_crossentropy: 0.4233
# Epoch 45/100
# 454/454 [==============================] - 30s 65ms/step - loss: 0.4978 - acc: 0.7730 - recall: 0.4832 - precision: 0.5601 - binary_crossentropy: 0.4973 - val_loss: 0.4195 - val_acc: 0.8021 - val_recall: 0.4908 - val_precision: 0.6433 - val_binary_crossentropy: 0.4223
# Epoch 46/100
# 454/454 [==============================] - 30s 65ms/step - loss: 0.5053 - acc: 0.7659 - recall: 0.4738 - precision: 0.5436 - binary_crossentropy: 0.5047 - val_loss: 0.4178 - val_acc: 0.8019 - val_recall: 0.4887 - val_precision: 0.6432 - val_binary_crossentropy: 0.4206
# Epoch 47/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.4987 - acc: 0.7739 - recall: 0.4765 - precision: 0.5634 - binary_crossentropy: 0.4982 - val_loss: 0.4184 - val_acc: 0.8021 - val_recall: 0.4846 - val_precision: 0.6457 - val_binary_crossentropy: 0.4212
# Epoch 48/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.4974 - acc: 0.7707 - recall: 0.4778 - precision: 0.5551 - binary_crossentropy: 0.4968 - val_loss: 0.4174 - val_acc: 0.8008 - val_recall: 0.4877 - val_precision: 0.6402 - val_binary_crossentropy: 0.4201
# Epoch 49/100
# 454/454 [==============================] - 30s 65ms/step - loss: 0.4946 - acc: 0.7722 - recall: 0.4861 - precision: 0.5577 - binary_crossentropy: 0.4941 - val_loss: 0.4171 - val_acc: 0.8019 - val_recall: 0.4825 - val_precision: 0.6456 - val_binary_crossentropy: 0.4199
# Epoch 50/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.4973 - acc: 0.7726 - recall: 0.4744 - precision: 0.5604 - binary_crossentropy: 0.4966 - val_loss: 0.4171 - val_acc: 0.8011 - val_recall: 0.4856 - val_precision: 0.6418 - val_binary_crossentropy: 0.4198
# Epoch 51/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.4960 - acc: 0.7707 - recall: 0.4747 - precision: 0.5555 - binary_crossentropy: 0.4954 - val_loss: 0.4162 - val_acc: 0.8006 - val_recall: 0.4877 - val_precision: 0.6393 - val_binary_crossentropy: 0.4189
# Epoch 52/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.4896 - acc: 0.7750 - recall: 0.4934 - precision: 0.5638 - binary_crossentropy: 0.4890 - val_loss: 0.4157 - val_acc: 0.8016 - val_recall: 0.4836 - val_precision: 0.6443 - val_binary_crossentropy: 0.4184
# Epoch 53/100
# 454/454 [==============================] - 30s 65ms/step - loss: 0.4951 - acc: 0.7707 - recall: 0.4716 - precision: 0.5559 - binary_crossentropy: 0.4946 - val_loss: 0.4142 - val_acc: 0.8019 - val_recall: 0.4867 - val_precision: 0.6440 - val_binary_crossentropy: 0.4169
# Epoch 54/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.4818 - acc: 0.7781 - recall: 0.4894 - precision: 0.5724 - binary_crossentropy: 0.4813 - val_loss: 0.4146 - val_acc: 0.8029 - val_recall: 0.4908 - val_precision: 0.6459 - val_binary_crossentropy: 0.4174
# Epoch 55/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.4866 - acc: 0.7761 - recall: 0.4832 - precision: 0.5683 - binary_crossentropy: 0.4861 - val_loss: 0.4138 - val_acc: 0.8034 - val_recall: 0.4856 - val_precision: 0.6497 - val_binary_crossentropy: 0.4165
# Epoch 56/100
# 454/454 [==============================] - 29s 65ms/step - loss: 0.4845 - acc: 0.7761 - recall: 0.4907 - precision: 0.5671 - binary_crossentropy: 0.4841 - val_loss: 0.4136 - val_acc: 0.8037 - val_recall: 0.4815 - val_precision: 0.6523 - val_binary_crossentropy: 0.4164
# Epoch 57/100
# 454/454 [==============================] - 30s 65ms/step - loss: 0.4829 - acc: 0.7786 - recall: 0.4805 - precision: 0.5753 - binary_crossentropy: 0.4823 - val_loss: 0.4126 - val_acc: 0.8042 - val_recall: 0.4805 - val_precision: 0.6545 - val_binary_crossentropy: 0.4154
# Epoch 58/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.4850 - acc: 0.7754 - recall: 0.4749 - precision: 0.5677 - binary_crossentropy: 0.4845 - val_loss: 0.4120 - val_acc: 0.8053 - val_recall: 0.4979 - val_precision: 0.6510 - val_binary_crossentropy: 0.4147
# Epoch 59/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.4838 - acc: 0.7755 - recall: 0.4834 - precision: 0.5667 - binary_crossentropy: 0.4833 - val_loss: 0.4118 - val_acc: 0.8060 - val_recall: 0.4867 - val_precision: 0.6583 - val_binary_crossentropy: 0.4146
# Epoch 60/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.4848 - acc: 0.7728 - recall: 0.4771 - precision: 0.5606 - binary_crossentropy: 0.4843 - val_loss: 0.4115 - val_acc: 0.8040 - val_recall: 0.4795 - val_precision: 0.6541 - val_binary_crossentropy: 0.4143
# Epoch 61/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.4828 - acc: 0.7786 - recall: 0.4914 - precision: 0.5734 - binary_crossentropy: 0.4822 - val_loss: 0.4113 - val_acc: 0.8058 - val_recall: 0.4877 - val_precision: 0.6570 - val_binary_crossentropy: 0.4141
# Epoch 62/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.4738 - acc: 0.7788 - recall: 0.4867 - precision: 0.5749 - binary_crossentropy: 0.4733 - val_loss: 0.4104 - val_acc: 0.8047 - val_recall: 0.4918 - val_precision: 0.6517 - val_binary_crossentropy: 0.4131
# Epoch 63/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.4787 - acc: 0.7756 - recall: 0.4870 - precision: 0.5664 - binary_crossentropy: 0.4781 - val_loss: 0.4106 - val_acc: 0.8053 - val_recall: 0.4774 - val_precision: 0.6596 - val_binary_crossentropy: 0.4134
# Epoch 64/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.4816 - acc: 0.7748 - recall: 0.4878 - precision: 0.5642 - binary_crossentropy: 0.4812 - val_loss: 0.4097 - val_acc: 0.8060 - val_recall: 0.4938 - val_precision: 0.6553 - val_binary_crossentropy: 0.4124
# Epoch 65/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.4772 - acc: 0.7774 - recall: 0.4852 - precision: 0.5713 - binary_crossentropy: 0.4767 - val_loss: 0.4088 - val_acc: 0.8058 - val_recall: 0.4846 - val_precision: 0.6583 - val_binary_crossentropy: 0.4116
# Epoch 66/100
# 454/454 [==============================] - 30s 67ms/step - loss: 0.4716 - acc: 0.7808 - recall: 0.4901 - precision: 0.5795 - binary_crossentropy: 0.4711 - val_loss: 0.4083 - val_acc: 0.8084 - val_recall: 0.4918 - val_precision: 0.6644 - val_binary_crossentropy: 0.4111
# Epoch 67/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.4738 - acc: 0.7768 - recall: 0.4903 - precision: 0.5689 - binary_crossentropy: 0.4733 - val_loss: 0.4080 - val_acc: 0.8102 - val_recall: 0.5000 - val_precision: 0.6671 - val_binary_crossentropy: 0.4107
# Epoch 68/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.4704 - acc: 0.7794 - recall: 0.4894 - precision: 0.5759 - binary_crossentropy: 0.4699 - val_loss: 0.4075 - val_acc: 0.8089 - val_recall: 0.4949 - val_precision: 0.6648 - val_binary_crossentropy: 0.4102
# Epoch 69/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.4735 - acc: 0.7787 - recall: 0.4783 - precision: 0.5762 - binary_crossentropy: 0.4729 - val_loss: 0.4070 - val_acc: 0.8086 - val_recall: 0.5010 - val_precision: 0.6612 - val_binary_crossentropy: 0.4098
# Epoch 70/100
# 454/454 [==============================] - 30s 67ms/step - loss: 0.4776 - acc: 0.7758 - recall: 0.4796 - precision: 0.5681 - binary_crossentropy: 0.4770 - val_loss: 0.4068 - val_acc: 0.8086 - val_recall: 0.5021 - val_precision: 0.6608 - val_binary_crossentropy: 0.4096
# Epoch 71/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.4736 - acc: 0.7790 - recall: 0.4869 - precision: 0.5754 - binary_crossentropy: 0.4732 - val_loss: 0.4059 - val_acc: 0.8102 - val_recall: 0.5051 - val_precision: 0.6649 - val_binary_crossentropy: 0.4085
# Epoch 72/100
# 454/454 [==============================] - 30s 66ms/step - loss: 0.4760 - acc: 0.7765 - recall: 0.4854 - precision: 0.5689 - binary_crossentropy: 0.4755 - val_loss: 0.4058 - val_acc: 0.8102 - val_recall: 0.5062 - val_precision: 0.6644 - val_binary_crossentropy: 0.4085
# Epoch 73/100
# 454/454 [==============================] - 29s 64ms/step - loss: 0.4675 - acc: 0.7818 - recall: 0.4961 - precision: 0.5812 - binary_crossentropy: 0.4671 - val_loss: 0.4055 - val_acc: 0.8097 - val_recall: 0.4969 - val_precision: 0.6667 - val_binary_crossentropy: 0.4082
# Epoch 74/100
# 250/454 [===============>..............] - ETA: 12s - loss: 0.4749 - acc: 0.7801 - recall: 0.4856 - precision: 0.5756 - binary_crossentropy: 0.4745

# %%
####################################
# # Plot the Performance Results # #
####################################

def smooth_curve(points,factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous*factor+point*(1-factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# Plot the loss and accuracy of the model over the train/val datasets during training
acc = history_freeze.history['acc']
val_acc = history_freeze.history['val_acc']
loss = history_freeze.history['loss']
val_loss = history_freeze.history['val_loss']

epochs = range(1,len(acc) + 1)

plt.plot(epochs, smooth_curve(acc), 'bo', label='Training acc')
plt.plot(epochs, smooth_curve(val_acc), 'b', label='Validation acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, smooth_curve(loss), 'bo', label='Training loss')
plt.plot(epochs, smooth_curve(val_loss), 'b', label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# %%
best_train_acc = max(history_freeze.history['acc']) * 100
best_val_acc = max(history_freeze.history['val_acc']) * 100

print('Best train acc:  {:2.2f}%'.format(best_train_acc))
print('Best val acc: {:2.2f}%'.format(best_val_acc))

# %%
# %cd /kaggle/working

# %%
os.getcwd()

# %%
# !mkdir Models
# %cd Models
model.save('Behold_Net8.h5')

# %% [markdown]
# # Model Testing and Exporting Predictions

# %%
# %cd /kaggle/input/test_images/test_images

# %%
import re
testimgs =  os.listdir("/kaggle/input/test_images/test_images")
testimgs.sort(key=lambda f: int(re.sub('\D', '', f)))
testimgs

# %%
# list of probabiliy predictions on test set
probabilities = []

# list of binary predictions on test set
binaries = []

# Get the names of the test images to put into a csv file with predictions 
test_images = []

for testfiles in testimgs:
  # print(testfiles)
    testfiles_noext = os.path.splitext(testfiles)[0]
    test_images.append(testfiles_noext)

    testimg = image.load_img(testfiles,target_size = (128, 128, 3))
    testimg = image.img_to_array(testimg)
    testimg = testimg/255.0
    testimg = testimg.reshape(1, 128, 128, 3)
    t_prob = model.predict(testimg)

    probabilities.append(t_prob[0])

    empty_list = []

    # 50% threshold since each prediction is just a binary classification problem
    # for each class
    for t in range(len(t_prob[0])):
        if t_prob[0][t] < 0.5:
            empty_list.append(np.int(0))
        elif t_prob[0][t] > 0.5:
            empty_list.append(np.int(1))
    empty_list = np.array(empty_list)

    binaries.append(empty_list)

# %%
len(test_images)

# %%
os.getcwd()

# %%
len(probabilities)

# %%
probabilities[0:10]

# %%
len(binaries)

# %%
binaries[0:10]

# %%
probabilities = np.array(probabilities)
binaries = np.array(binaries)

# %%
probabilities.shape

# %%
binaries.shape

# %%
print(type(probabilities))
print(type(binaries))

# %%
# %cd /kaggle/working

# %%
# %mkdir Predictions
# %cd Predictions

# %%
test_images = np.array(test_images)

# %%
df = pd.DataFrame(data = probabilities, columns = ['epidural', 'intraparenchymal',	'subarachnoid'])
df.insert(0,"ID",test_images)
df

# %%
df2 = pd.DataFrame(data = binaries, columns = ['epidural', 'intraparenchymal',	'subarachnoid'])
df2.insert(0,"ID",test_images)
df2

# %%
df.to_csv('/kaggle/working/Predictions/probabilities.csv',index=True)
df2.to_csv('/kaggle/working/Predictions/binary_preds.csv',index=True)

# %%
# %pwd

# %%
from sklearn.metrics import average_precision_score
y_true = y_val
y_scores = model.predict(X_val)

print(len(y_true))
print(len(y_scores))

average_precision_score(y_true, y_scores)
